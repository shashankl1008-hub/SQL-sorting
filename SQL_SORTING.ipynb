# %% [markdown]
# # SQL SORTING

# %% [markdown]
# Ans Q1--
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ans Q2--
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ans Q3--
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ans Q4--
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ans Q 5--
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ans Q6--
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ans Q7--
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ans Q8--
#
# ![image.png](data:image/png;base64,...)
